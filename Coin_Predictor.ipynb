# %% [markdown]
# <a href="https://colab.research.google.com/github/Brenton237/Machine-Learning-AI-Projects/blob/main/Crypto-Coin_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !pip install --upgrade pip

# %%
# !pip install tokenizers
# !pip install --upgrade tokenizers

# %%
# !pip install mwclient
# !pip install transformers

# %%
import mwclient
import time
site = mwclient.Site("en.wikipedia.org")
page = site.pages["Bitcoin"]

# %%
revs = list(page.revisions())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
revs[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# OrderedDict([('revid', 1165929069),
#              ('parentid', 1162174830),
#              ('user', 'Jtbobwaysf'),
#              ('timestamp',
#               time.struct_time(tm_year=2023, tm_mon=7, tm_mday=18, tm_hour=9, tm_min=3, tm_sec=38, tm_wday=1, tm_yday=199, tm_isdst=-1)),
#              ('comment', 'too much detail for lede')])

# %%
revs = sorted(revs, key = lambda rev: rev["timestamp"])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
revs[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# OrderedDict([('revid', 275832581),
#              ('parentid', 0),
#              ('user', 'Pratyeka'),
#              ('timestamp',
#               time.struct_time(tm_year=2009, tm_mon=3, tm_mday=8, tm_hour=16, tm_min=41, tm_sec=7, tm_wday=6, tm_yday=67, tm_isdst=-1)),
#              ('comment', 'creation (stub)')])

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")

def find_sentiment(text):
  sent = sentiment_pipeline([text[:250]])[0]
  score = sent["score"]
  if sent["label"] == "NEGATIVE":
    score *= -1
  return score
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:58: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   distutils.version.LooseVersion(required_tensorflow_version)):
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# /usr/local/lib/python3.10/dist-packages/transformers/models/open_llama/modeling_open_llama.py:42: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   logger.warn(
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
edits = {}

for rev in revs:
  date = time.strftime("%Y-%m-%d", rev["timestamp"])

  if date not in edits:
    edits[date] = dict(sentiments = list(), edit_count = 0)

    edits[date]["edit_count"] +=1
    comment = rev.get("comment", "")
    edits[date]["sentiments"].append(find_sentiment(comment))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from statistics import mean

for key in edits:
    if len(edits[key]["sentiments"]) > 0:
        edits[key]["sentiment"] = mean(edits[key]["sentiments"])
        edits[key]["neg_sentiment"] = len([s for s in edits[key]["sentiments"] if s < 0]) / len(edits[key]["sentiments"])
    else:
        edits[key]["sentiment"] = 0
        edits[key]["neg_sentiment"] = 0

    del edits[key]["sentiments"]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
edits
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'2009-03-08': {'edit_count': 1,
#   'sentiment': -0.9905919432640076,
#   'neg_sentiment': 1.0},
#  '2009-08-05': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-08-06': {'edit_count': 1,
#   'sentiment': 0.995745837688446,
#   'neg_sentiment': 0.0},
#  '2009-08-14': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2009-10-13': {'edit_count': 1,
#   'sentiment': 0.540434718132019,
#   'neg_sentiment': 0.0},
#  '2009-11-18': {'edit_count': 1,
#   'sentiment': 0.8839504718780518,
#   'neg_sentiment': 0.0},
#  '2009-12-08': {'edit_count': 1,
#   'sentiment': -0.9869275689125061,
#   'neg_sentiment': 1.0},
#  '2009-12-17': {'edit_count': 1,
#   'sentiment': -0.9975171089172363,
#   'neg_sentiment': 1.0},
#  '2010-02-23': {'edit_count': 1,
#   'sentiment': -0.9994946718215942,
#   'neg_sentiment': 1.0},
#  '2010-03-18': {'edit_count': 1,
#   'sentiment': 0.8758771419525146,
#   'neg_sentiment': 0.0},
#  '2010-04-13': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2010-04-15': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2010-04-28': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-05-13': {'edit_count': 1,
#   'sentiment': -0.9664837121963501,
#   'neg_sentiment': 1.0},
#  '2010-06-17': {'edit_count': 1,
#   'sentiment': 0.995745837688446,
#   'neg_sentiment': 0.0},
#  '2010-06-18': {'edit_count': 1,
#   'sentiment': 0.6754599809646606,
#   'neg_sentiment': 0.0},
#  '2010-06-19': {'edit_count': 1,
#   'sentiment': 0.9875591397285461,
#   'neg_sentiment': 0.0},
#  '2010-06-20': {'edit_count': 1,
#   'sentiment': 0.9875591397285461,
#   'neg_sentiment': 0.0},
#  '2010-06-21': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-06-23': {'edit_count': 1,
#   'sentiment': 0.9360668659210205,
#   'neg_sentiment': 0.0},
#  '2010-06-28': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-06-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-07-05': {'edit_count': 1,
#   'sentiment': 0.9360668659210205,
#   'neg_sentiment': 0.0},
#  '2010-07-07': {'edit_count': 1,
#   'sentiment': -0.9996860027313232,
#   'neg_sentiment': 1.0},
#  '2010-07-08': {'edit_count': 1,
#   'sentiment': 0.9991004467010498,
#   'neg_sentiment': 0.0},
#  '2010-07-09': {'edit_count': 1,
#   'sentiment': -0.9049851894378662,
#   'neg_sentiment': 1.0},
#  '2010-07-11': {'edit_count': 1,
#   'sentiment': 0.658440113067627,
#   'neg_sentiment': 0.0},
#  '2010-07-12': {'edit_count': 1,
#   'sentiment': -0.9998044371604919,
#   'neg_sentiment': 1.0},
#  '2010-07-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-07-14': {'edit_count': 1,
#   'sentiment': -0.9994907379150391,
#   'neg_sentiment': 1.0},
#  '2010-07-15': {'edit_count': 1,
#   'sentiment': -0.9955335855484009,
#   'neg_sentiment': 1.0},
#  '2010-07-16': {'edit_count': 1,
#   'sentiment': 0.9878523349761963,
#   'neg_sentiment': 0.0},
#  '2010-07-18': {'edit_count': 1,
#   'sentiment': 0.6105566024780273,
#   'neg_sentiment': 0.0},
#  '2010-07-19': {'edit_count': 1,
#   'sentiment': 0.8669617176055908,
#   'neg_sentiment': 0.0},
#  '2010-07-21': {'edit_count': 1,
#   'sentiment': -0.9986214637756348,
#   'neg_sentiment': 1.0},
#  '2010-07-22': {'edit_count': 1,
#   'sentiment': -0.9933270215988159,
#   'neg_sentiment': 1.0},
#  '2010-07-25': {'edit_count': 1,
#   'sentiment': 0.7879021167755127,
#   'neg_sentiment': 0.0},
#  '2010-07-29': {'edit_count': 1,
#   'sentiment': 0.9859933853149414,
#   'neg_sentiment': 0.0},
#  '2010-08-03': {'edit_count': 1,
#   'sentiment': -0.9960501790046692,
#   'neg_sentiment': 1.0},
#  '2010-08-12': {'edit_count': 1,
#   'sentiment': 0.9703167080879211,
#   'neg_sentiment': 0.0},
#  '2010-08-14': {'edit_count': 1,
#   'sentiment': -0.9994552731513977,
#   'neg_sentiment': 1.0},
#  '2010-08-18': {'edit_count': 1,
#   'sentiment': -0.999642014503479,
#   'neg_sentiment': 1.0},
#  '2010-08-21': {'edit_count': 1,
#   'sentiment': -0.9951969981193542,
#   'neg_sentiment': 1.0},
#  '2010-09-20': {'edit_count': 1,
#   'sentiment': -0.9341223239898682,
#   'neg_sentiment': 1.0},
#  '2010-09-26': {'edit_count': 1,
#   'sentiment': -0.9993003606796265,
#   'neg_sentiment': 1.0},
#  '2010-09-27': {'edit_count': 1,
#   'sentiment': -0.9997001886367798,
#   'neg_sentiment': 1.0},
#  '2010-09-29': {'edit_count': 1,
#   'sentiment': -0.9989383816719055,
#   'neg_sentiment': 1.0},
#  '2010-10-02': {'edit_count': 1,
#   'sentiment': -0.9153556823730469,
#   'neg_sentiment': 1.0},
#  '2010-10-05': {'edit_count': 1,
#   'sentiment': -0.994151771068573,
#   'neg_sentiment': 1.0},
#  '2010-10-19': {'edit_count': 1,
#   'sentiment': 0.6267775893211365,
#   'neg_sentiment': 0.0},
#  '2010-11-10': {'edit_count': 1,
#   'sentiment': 0.9957578778266907,
#   'neg_sentiment': 0.0},
#  '2010-11-11': {'edit_count': 1,
#   'sentiment': -0.9928996562957764,
#   'neg_sentiment': 1.0},
#  '2010-11-25': {'edit_count': 1,
#   'sentiment': -0.9625310301780701,
#   'neg_sentiment': 1.0},
#  '2010-11-26': {'edit_count': 1,
#   'sentiment': 0.9957578778266907,
#   'neg_sentiment': 0.0},
#  '2010-11-28': {'edit_count': 1,
#   'sentiment': -0.9982038736343384,
#   'neg_sentiment': 1.0},
#  '2010-12-01': {'edit_count': 1,
#   'sentiment': 0.9957578778266907,
#   'neg_sentiment': 0.0},
#  '2010-12-05': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-12-10': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-12-11': {'edit_count': 1,
#   'sentiment': -0.985965371131897,
#   'neg_sentiment': 1.0},
#  '2010-12-12': {'edit_count': 1,
#   'sentiment': -0.9911536574363708,
#   'neg_sentiment': 1.0},
#  '2010-12-13': {'edit_count': 1,
#   'sentiment': -0.9909906387329102,
#   'neg_sentiment': 1.0},
#  '2010-12-14': {'edit_count': 1,
#   'sentiment': -0.9916331768035889,
#   'neg_sentiment': 1.0},
#  '2010-12-15': {'edit_count': 1,
#   'sentiment': -0.9993361830711365,
#   'neg_sentiment': 1.0},
#  '2010-12-16': {'edit_count': 1,
#   'sentiment': -0.9997054934501648,
#   'neg_sentiment': 1.0},
#  '2010-12-17': {'edit_count': 1,
#   'sentiment': -0.9683456420898438,
#   'neg_sentiment': 1.0},
#  '2010-12-18': {'edit_count': 1,
#   'sentiment': -0.9997377991676331,
#   'neg_sentiment': 1.0},
#  '2010-12-19': {'edit_count': 1,
#   'sentiment': -0.9992154836654663,
#   'neg_sentiment': 1.0},
#  '2010-12-20': {'edit_count': 1,
#   'sentiment': 0.9979097247123718,
#   'neg_sentiment': 0.0},
#  '2010-12-21': {'edit_count': 1,
#   'sentiment': -0.9935435056686401,
#   'neg_sentiment': 1.0},
#  '2010-12-22': {'edit_count': 1,
#   'sentiment': 0.6994768977165222,
#   'neg_sentiment': 0.0},
#  '2010-12-23': {'edit_count': 1,
#   'sentiment': 0.9408825039863586,
#   'neg_sentiment': 0.0},
#  '2010-12-24': {'edit_count': 1,
#   'sentiment': -0.9991777539253235,
#   'neg_sentiment': 1.0},
#  '2011-01-01': {'edit_count': 1,
#   'sentiment': 0.9105638861656189,
#   'neg_sentiment': 0.0},
#  '2011-01-06': {'edit_count': 1,
#   'sentiment': -0.9996631145477295,
#   'neg_sentiment': 1.0},
#  '2011-01-07': {'edit_count': 1,
#   'sentiment': -0.9908575415611267,
#   'neg_sentiment': 1.0},
#  '2011-01-10': {'edit_count': 1,
#   'sentiment': 0.9672892689704895,
#   'neg_sentiment': 0.0},
#  '2011-01-11': {'edit_count': 1,
#   'sentiment': -0.9997628331184387,
#   'neg_sentiment': 1.0},
#  '2011-01-14': {'edit_count': 1,
#   'sentiment': 0.5266938805580139,
#   'neg_sentiment': 0.0},
#  '2011-01-16': {'edit_count': 1,
#   'sentiment': 0.6055784225463867,
#   'neg_sentiment': 0.0},
#  '2011-01-17': {'edit_count': 1,
#   'sentiment': -0.9371861815452576,
#   'neg_sentiment': 1.0},
#  '2011-01-20': {'edit_count': 1,
#   'sentiment': -0.6644992828369141,
#   'neg_sentiment': 1.0},
#  '2011-01-21': {'edit_count': 1,
#   'sentiment': 0.9408825039863586,
#   'neg_sentiment': 0.0},
#  '2011-01-22': {'edit_count': 1,
#   'sentiment': -0.9456276297569275,
#   'neg_sentiment': 1.0},
#  '2011-01-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-01-25': {'edit_count': 1,
#   'sentiment': -0.559001624584198,
#   'neg_sentiment': 1.0},
#  '2011-01-26': {'edit_count': 1,
#   'sentiment': -0.9716882705688477,
#   'neg_sentiment': 1.0},
#  '2011-01-29': {'edit_count': 1,
#   'sentiment': -0.9884641766548157,
#   'neg_sentiment': 1.0},
#  '2011-01-31': {'edit_count': 1,
#   'sentiment': -0.9942212104797363,
#   'neg_sentiment': 1.0},
#  '2011-02-01': {'edit_count': 1,
#   'sentiment': -0.9900445938110352,
#   'neg_sentiment': 1.0},
#  '2011-02-04': {'edit_count': 1,
#   'sentiment': -0.9996967315673828,
#   'neg_sentiment': 1.0},
#  '2011-02-05': {'edit_count': 1,
#   'sentiment': -0.998088538646698,
#   'neg_sentiment': 1.0},
#  '2011-02-06': {'edit_count': 1,
#   'sentiment': -0.9991208910942078,
#   'neg_sentiment': 1.0},
#  '2011-02-10': {'edit_count': 1,
#   'sentiment': -0.9937098026275635,
#   'neg_sentiment': 1.0},
#  '2011-02-11': {'edit_count': 1,
#   'sentiment': -0.9964062571525574,
#   'neg_sentiment': 1.0},
#  '2011-02-12': {'edit_count': 1,
#   'sentiment': -0.9933351278305054,
#   'neg_sentiment': 1.0},
#  '2011-02-13': {'edit_count': 1,
#   'sentiment': -0.8082681894302368,
#   'neg_sentiment': 1.0},
#  '2011-02-14': {'edit_count': 1,
#   'sentiment': -0.9961602687835693,
#   'neg_sentiment': 1.0},
#  '2011-02-15': {'edit_count': 1,
#   'sentiment': -0.9864668250083923,
#   'neg_sentiment': 1.0},
#  '2011-02-17': {'edit_count': 1,
#   'sentiment': -0.9914788603782654,
#   'neg_sentiment': 1.0},
#  '2011-02-18': {'edit_count': 1,
#   'sentiment': -0.580612301826477,
#   'neg_sentiment': 1.0},
#  '2011-02-20': {'edit_count': 1,
#   'sentiment': -0.9961812496185303,
#   'neg_sentiment': 1.0},
#  '2011-02-23': {'edit_count': 1,
#   'sentiment': 0.6554882526397705,
#   'neg_sentiment': 0.0},
#  '2011-02-24': {'edit_count': 1,
#   'sentiment': 0.9833250045776367,
#   'neg_sentiment': 0.0},
#  '2011-02-25': {'edit_count': 1,
#   'sentiment': -0.6478725075721741,
#   'neg_sentiment': 1.0},
#  '2011-02-26': {'edit_count': 1,
#   'sentiment': 0.9926506876945496,
#   'neg_sentiment': 0.0},
#  '2011-02-28': {'edit_count': 1,
#   'sentiment': 0.9858648777008057,
#   'neg_sentiment': 0.0},
#  '2011-03-01': {'edit_count': 1,
#   'sentiment': 0.8048122525215149,
#   'neg_sentiment': 0.0},
#  '2011-03-04': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-03-07': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-03-08': {'edit_count': 1,
#   'sentiment': 0.6523979902267456,
#   'neg_sentiment': 0.0},
#  '2011-03-11': {'edit_count': 1,
#   'sentiment': 0.8737884163856506,
#   'neg_sentiment': 0.0},
#  '2011-03-12': {'edit_count': 1,
#   'sentiment': -0.9923986792564392,
#   'neg_sentiment': 1.0},
#  '2011-03-13': {'edit_count': 1,
#   'sentiment': -0.6153922080993652,
#   'neg_sentiment': 1.0},
#  '2011-03-14': {'edit_count': 1,
#   'sentiment': -0.9923911690711975,
#   'neg_sentiment': 1.0},
#  '2011-03-15': {'edit_count': 1,
#   'sentiment': -0.9711605310440063,
#   'neg_sentiment': 1.0},
#  '2011-03-17': {'edit_count': 1,
#   'sentiment': -0.9251039624214172,
#   'neg_sentiment': 1.0},
#  '2011-03-18': {'edit_count': 1,
#   'sentiment': 0.8889294862747192,
#   'neg_sentiment': 0.0},
#  '2011-03-19': {'edit_count': 1,
#   'sentiment': -0.9962666630744934,
#   'neg_sentiment': 1.0},
#  '2011-03-20': {'edit_count': 1,
#   'sentiment': 0.9894005656242371,
#   'neg_sentiment': 0.0},
#  '2011-03-21': {'edit_count': 1,
#   'sentiment': 0.8048122525215149,
#   'neg_sentiment': 0.0},
#  '2011-03-22': {'edit_count': 1,
#   'sentiment': 0.8048122525215149,
#   'neg_sentiment': 0.0},
#  '2011-03-23': {'edit_count': 1,
#   'sentiment': -0.9996017813682556,
#   'neg_sentiment': 1.0},
#  '2011-03-24': {'edit_count': 1,
#   'sentiment': -0.9965630173683167,
#   'neg_sentiment': 1.0},
#  '2011-03-25': {'edit_count': 1,
#   'sentiment': -0.9964498281478882,
#   'neg_sentiment': 1.0},
#  '2011-03-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-03-28': {'edit_count': 1,
#   'sentiment': 0.7468478083610535,
#   'neg_sentiment': 0.0},
#  '2011-03-29': {'edit_count': 1,
#   'sentiment': -0.9948830604553223,
#   'neg_sentiment': 1.0},
#  '2011-03-30': {'edit_count': 1,
#   'sentiment': 0.8153408169746399,
#   'neg_sentiment': 0.0},
#  '2011-04-02': {'edit_count': 1,
#   'sentiment': 0.9754456281661987,
#   'neg_sentiment': 0.0},
#  '2011-04-04': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-04-05': {'edit_count': 1,
#   'sentiment': -0.9985226988792419,
#   'neg_sentiment': 1.0},
#  '2011-04-06': {'edit_count': 1,
#   'sentiment': -0.9705725312232971,
#   'neg_sentiment': 1.0},
#  '2011-04-09': {'edit_count': 1,
#   'sentiment': 0.9991887211799622,
#   'neg_sentiment': 0.0},
#  '2011-04-11': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-04-12': {'edit_count': 1,
#   'sentiment': -0.9962294697761536,
#   'neg_sentiment': 1.0},
#  '2011-04-13': {'edit_count': 1,
#   'sentiment': -0.9992400407791138,
#   'neg_sentiment': 1.0},
#  '2011-04-14': {'edit_count': 1,
#   'sentiment': -0.9981020092964172,
#   'neg_sentiment': 1.0},
#  '2011-04-16': {'edit_count': 1,
#   'sentiment': -0.9973383545875549,
#   'neg_sentiment': 1.0},
#  '2011-04-17': {'edit_count': 1,
#   'sentiment': 0.9965644478797913,
#   'neg_sentiment': 0.0},
#  '2011-04-18': {'edit_count': 1,
#   'sentiment': -0.9990328550338745,
#   'neg_sentiment': 1.0},
#  '2011-04-19': {'edit_count': 1,
#   'sentiment': 0.9925560355186462,
#   'neg_sentiment': 0.0},
#  '2011-04-20': {'edit_count': 1,
#   'sentiment': -0.99940025806427,
#   'neg_sentiment': 1.0},
#  '2011-04-21': {'edit_count': 1,
#   'sentiment': -0.996119499206543,
#   'neg_sentiment': 1.0},
#  '2011-04-22': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-04-24': {'edit_count': 1,
#   'sentiment': 0.6554882526397705,
#   'neg_sentiment': 0.0},
#  '2011-04-25': {'edit_count': 1,
#   'sentiment': -0.995245635509491,
#   'neg_sentiment': 1.0},
#  '2011-04-26': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-04-27': {'edit_count': 1,
#   'sentiment': -0.9966471791267395,
#   'neg_sentiment': 1.0},
#  '2011-04-28': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-04-29': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-04-30': {'edit_count': 1,
#   'sentiment': 0.990734338760376,
#   'neg_sentiment': 0.0},
#  '2011-05-02': {'edit_count': 1,
#   'sentiment': -0.9992848038673401,
#   'neg_sentiment': 1.0},
#  '2011-05-03': {'edit_count': 1,
#   'sentiment': 0.6941722631454468,
#   'neg_sentiment': 0.0},
#  '2011-05-04': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-05-05': {'edit_count': 1,
#   'sentiment': 0.9984391331672668,
#   'neg_sentiment': 0.0},
#  '2011-05-06': {'edit_count': 1,
#   'sentiment': -0.6644992828369141,
#   'neg_sentiment': 1.0},
#  '2011-05-08': {'edit_count': 1,
#   'sentiment': -0.9983398914337158,
#   'neg_sentiment': 1.0},
#  '2011-05-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-05-10': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-05-11': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-05-12': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-05-14': {'edit_count': 1,
#   'sentiment': 0.6941722631454468,
#   'neg_sentiment': 0.0},
#  '2011-05-15': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-05-16': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-05-17': {'edit_count': 1,
#   'sentiment': 0.9747792482376099,
#   'neg_sentiment': 0.0},
#  '2011-05-18': {'edit_count': 1,
#   'sentiment': -0.9716083407402039,
#   'neg_sentiment': 1.0},
#  '2011-05-19': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-05-20': {'edit_count': 1,
#   'sentiment': -0.9951480031013489,
#   'neg_sentiment': 1.0},
#  '2011-05-21': {'edit_count': 1,
#   'sentiment': -0.985065758228302,
#   'neg_sentiment': 1.0},
#  '2011-05-22': {'edit_count': 1,
#   'sentiment': -0.9996566772460938,
#   'neg_sentiment': 1.0},
#  '2011-05-23': {'edit_count': 1,
#   'sentiment': -0.9982251524925232,
#   'neg_sentiment': 1.0},
#  '2011-05-24': {'edit_count': 1,
#   'sentiment': -0.999792754650116,
#   'neg_sentiment': 1.0},
#  '2011-05-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-05-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-05-27': {'edit_count': 1,
#   'sentiment': -0.9912882447242737,
#   'neg_sentiment': 1.0},
#  '2011-05-28': {'edit_count': 1,
#   'sentiment': -0.981084942817688,
#   'neg_sentiment': 1.0},
#  '2011-05-29': {'edit_count': 1,
#   'sentiment': -0.6447558999061584,
#   'neg_sentiment': 1.0},
#  '2011-05-30': {'edit_count': 1,
#   'sentiment': -0.9986005425453186,
#   'neg_sentiment': 1.0},
#  '2011-05-31': {'edit_count': 1,
#   'sentiment': -0.9816463589668274,
#   'neg_sentiment': 1.0},
#  '2011-06-01': {'edit_count': 1,
#   'sentiment': -0.9988498687744141,
#   'neg_sentiment': 1.0},
#  '2011-06-02': {'edit_count': 1,
#   'sentiment': -0.6644992828369141,
#   'neg_sentiment': 1.0},
#  '2011-06-03': {'edit_count': 1,
#   'sentiment': -0.9992156028747559,
#   'neg_sentiment': 1.0},
#  '2011-06-04': {'edit_count': 1,
#   'sentiment': -0.9729158878326416,
#   'neg_sentiment': 1.0},
#  '2011-06-05': {'edit_count': 1,
#   'sentiment': -0.989362895488739,
#   'neg_sentiment': 1.0},
#  '2011-06-06': {'edit_count': 1,
#   'sentiment': -0.8900179862976074,
#   'neg_sentiment': 1.0},
#  '2011-06-07': {'edit_count': 1,
#   'sentiment': 0.9937270879745483,
#   'neg_sentiment': 0.0},
#  '2011-06-08': {'edit_count': 1,
#   'sentiment': 0.6554882526397705,
#   'neg_sentiment': 0.0},
#  '2011-06-09': {'edit_count': 1,
#   'sentiment': 0.6941722631454468,
#   'neg_sentiment': 0.0},
#  '2011-06-10': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-06-11': {'edit_count': 1,
#   'sentiment': -0.992633044719696,
#   'neg_sentiment': 1.0},
#  '2011-06-12': {'edit_count': 1,
#   'sentiment': 0.9678489565849304,
#   'neg_sentiment': 0.0},
#  '2011-06-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-06-14': {'edit_count': 1,
#   'sentiment': -0.9683548212051392,
#   'neg_sentiment': 1.0},
#  '2011-06-15': {'edit_count': 1,
#   'sentiment': -0.9993682503700256,
#   'neg_sentiment': 1.0},
#  '2011-06-16': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-06-17': {'edit_count': 1,
#   'sentiment': -0.9993733763694763,
#   'neg_sentiment': 1.0},
#  '2011-06-18': {'edit_count': 1,
#   'sentiment': -0.9986922144889832,
#   'neg_sentiment': 1.0},
#  '2011-06-19': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2011-06-20': {'edit_count': 1,
#   'sentiment': -0.9850126504898071,
#   'neg_sentiment': 1.0},
#  '2011-06-21': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2011-06-22': {'edit_count': 1,
#   'sentiment': -0.9994675517082214,
#   'neg_sentiment': 1.0},
#  '2011-06-23': {'edit_count': 1,
#   'sentiment': -0.987342357635498,
#   'neg_sentiment': 1.0},
#  '2011-06-24': {'edit_count': 1,
#   'sentiment': -0.9266188144683838,
#   'neg_sentiment': 1.0},
#  '2011-06-25': {'edit_count': 1,
#   'sentiment': -0.9989629983901978,
#   'neg_sentiment': 1.0},
#  '2011-06-26': {'edit_count': 1,
#   'sentiment': -0.7913892269134521,
#   'neg_sentiment': 1.0},
#  '2011-06-27': {'edit_count': 1,
#   'sentiment': -0.9850126504898071,
#   'neg_sentiment': 1.0},
#  '2011-06-28': {'edit_count': 1,
#   'sentiment': -0.830633282661438,
#   'neg_sentiment': 1.0},
#  '2011-06-29': {'edit_count': 1,
#   'sentiment': -0.9959394931793213,
#   'neg_sentiment': 1.0},
#  '2011-06-30': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-01': {'edit_count': 1,
#   'sentiment': 0.9916595816612244,
#   'neg_sentiment': 0.0},
#  '2011-07-02': {'edit_count': 1,
#   'sentiment': 0.9955295920372009,
#   'neg_sentiment': 0.0},
#  '2011-07-03': {'edit_count': 1,
#   'sentiment': -0.9823566675186157,
#   'neg_sentiment': 1.0},
#  '2011-07-04': {'edit_count': 1,
#   'sentiment': -0.9957754015922546,
#   'neg_sentiment': 1.0},
#  '2011-07-05': {'edit_count': 1,
#   'sentiment': -0.9991480112075806,
#   'neg_sentiment': 1.0},
#  '2011-07-06': {'edit_count': 1,
#   'sentiment': -0.9987900853157043,
#   'neg_sentiment': 1.0},
#  '2011-07-07': {'edit_count': 1,
#   'sentiment': 0.7538614273071289,
#   'neg_sentiment': 0.0},
#  '2011-07-08': {'edit_count': 1,
#   'sentiment': -0.9823566675186157,
#   'neg_sentiment': 1.0},
#  '2011-07-09': {'edit_count': 1,
#   'sentiment': -0.9823566675186157,
#   'neg_sentiment': 1.0},
#  '2011-07-10': {'edit_count': 1,
#   'sentiment': -0.9940075874328613,
#   'neg_sentiment': 1.0},
#  '2011-07-11': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-12': {'edit_count': 1,
#   'sentiment': -0.9979705214500427,
#   'neg_sentiment': 1.0},
#  '2011-07-13': {'edit_count': 1,
#   'sentiment': -0.9993394017219543,
#   'neg_sentiment': 1.0},
#  '2011-07-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-15': {'edit_count': 1,
#   'sentiment': -0.941382646560669,
#   'neg_sentiment': 1.0},
#  '2011-07-16': {'edit_count': 1,
#   'sentiment': -0.9978852868080139,
#   'neg_sentiment': 1.0},
#  '2011-07-17': {'edit_count': 1,
#   'sentiment': -0.9991002082824707,
#   'neg_sentiment': 1.0},
#  '2011-07-18': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-19': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-21': {'edit_count': 1,
#   'sentiment': -0.9724799394607544,
#   'neg_sentiment': 1.0},
#  '2011-07-22': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-23': {'edit_count': 1,
#   'sentiment': -0.997351884841919,
#   'neg_sentiment': 1.0},
#  '2011-07-24': {'edit_count': 1,
#   'sentiment': 0.9271292686462402,
#   'neg_sentiment': 0.0},
#  '2011-07-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-28': {'edit_count': 1,
#   'sentiment': 0.6554882526397705,
#   'neg_sentiment': 0.0},
#  '2011-07-29': {'edit_count': 1,
#   'sentiment': 0.9678489565849304,
#   'neg_sentiment': 0.0},
#  '2011-07-30': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-31': {'edit_count': 1,
#   'sentiment': -0.9718877673149109,
#   'neg_sentiment': 1.0},
#  '2011-08-02': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-08-03': {'edit_count': 1,
#   'sentiment': 0.9988102912902832,
#   'neg_sentiment': 0.0},
#  '2011-08-04': {'edit_count': 1,
#   'sentiment': -0.9997959733009338,
#   'neg_sentiment': 1.0},
#  '2011-08-05': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-08-07': {'edit_count': 1,
#   'sentiment': -0.9997252821922302,
#   'neg_sentiment': 1.0},
#  '2011-08-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-08-09': {'edit_count': 1,
#   'sentiment': -0.9977178573608398,
#   'neg_sentiment': 1.0},
#  '2011-08-10': {'edit_count': 1,
#   'sentiment': -0.9720867276191711,
#   'neg_sentiment': 1.0},
#  '2011-08-11': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-08-12': {'edit_count': 1,
#   'sentiment': -0.9980623126029968,
#   'neg_sentiment': 1.0},
#  '2011-08-15': {'edit_count': 1,
#   'sentiment': -0.9994683861732483,
#   'neg_sentiment': 1.0},
#  '2011-08-16': {'edit_count': 1,
#   'sentiment': -0.9736192226409912,
#   'neg_sentiment': 1.0},
#  '2011-08-17': {'edit_count': 1,
#   'sentiment': -0.9515321254730225,
#   'neg_sentiment': 1.0},
#  '2011-08-19': {'edit_count': 1,
#   'sentiment': -0.9958387613296509,
#   'neg_sentiment': 1.0},
#  '2011-08-20': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-08-22': {'edit_count': 1,
#   'sentiment': 0.9917397499084473,
#   'neg_sentiment': 0.0},
#  '2011-08-23': {'edit_count': 1,
#   'sentiment': 0.9271292686462402,
#   'neg_sentiment': 0.0},
#  '2011-08-24': {'edit_count': 1,
#   'sentiment': -0.6644992828369141,
#   'neg_sentiment': 1.0},
#  '2011-08-25': {'edit_count': 1,
#   'sentiment': -0.967137336730957,
#   'neg_sentiment': 1.0},
#  '2011-08-26': {'edit_count': 1,
#   'sentiment': -0.996552586555481,
#   'neg_sentiment': 1.0},
#  '2011-08-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-08-31': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2011-09-01': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-09-02': {'edit_count': 1,
#   'sentiment': -0.9963033199310303,
#   'neg_sentiment': 1.0},
#  '2011-09-03': {'edit_count': 1,
#   'sentiment': -0.9779974818229675,
#   'neg_sentiment': 1.0},
#  '2011-09-04': {'edit_count': 1,
#   'sentiment': 0.9889422655105591,
#   'neg_sentiment': 0.0},
#  '2011-09-05': {'edit_count': 1,
#   'sentiment': -0.9876619577407837,
#   'neg_sentiment': 1.0},
#  '2011-09-06': {'edit_count': 1,
#   'sentiment': -0.9993465542793274,
#   'neg_sentiment': 1.0},
#  '2011-09-07': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-09-08': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-09-09': {'edit_count': 1,
#   'sentiment': -0.9992613196372986,
#   'neg_sentiment': 1.0},
#  '2011-09-13': {'edit_count': 1,
#   'sentiment': -0.9939253926277161,
#   'neg_sentiment': 1.0},
#  '2011-09-14': {'edit_count': 1,
#   'sentiment': 0.998339056968689,
#   'neg_sentiment': 0.0},
#  '2011-09-15': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2011-09-16': {'edit_count': 1,
#   'sentiment': -0.9990200996398926,
#   'neg_sentiment': 1.0},
#  '2011-09-17': {'edit_count': 1,
#   'sentiment': -0.9961752891540527,
#   'neg_sentiment': 1.0},
#  '2011-09-18': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-09-19': {'edit_count': 1,
#   'sentiment': 0.9676259756088257,
#   'neg_sentiment': 0.0},
#  '2011-09-20': {'edit_count': 1,
#   'sentiment': 0.6554882526397705,
#   'neg_sentiment': 0.0},
#  '2011-09-21': {'edit_count': 1,
#   'sentiment': 0.7407242059707642,
#   'neg_sentiment': 0.0},
#  '2011-09-22': {'edit_count': 1,
#   'sentiment': -0.9625430703163147,
#   'neg_sentiment': 1.0},
#  '2011-09-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-09-26': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2011-09-27': {'edit_count': 1,
#   'sentiment': -0.8166530728340149,
#   'neg_sentiment': 1.0},
#  '2011-09-29': {'edit_count': 1,
#   'sentiment': -0.9991542100906372,
#   'neg_sentiment': 1.0},
#  '2011-09-30': {'edit_count': 1,
#   'sentiment': -0.9997238516807556,
#   'neg_sentiment': 1.0},
#  '2011-10-01': {'edit_count': 1,
#   'sentiment': 0.6554882526397705,
#   'neg_sentiment': 0.0},
#  '2011-10-02': {'edit_count': 1,
#   'sentiment': -0.9822821617126465,
#   'neg_sentiment': 1.0},
#  '2011-10-04': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2011-10-05': {'edit_count': 1,
#   'sentiment': -0.7790735960006714,
#   'neg_sentiment': 1.0},
#  '2011-10-06': {'edit_count': 1,
#   'sentiment': -0.993718147277832,
#   'neg_sentiment': 1.0},
#  '2011-10-07': {'edit_count': 1,
#   'sentiment': -0.9996753931045532,
#   'neg_sentiment': 1.0},
#  '2011-10-08': {'edit_count': 1,
#   'sentiment': 0.9482848048210144,
#   'neg_sentiment': 0.0},
#  '2011-10-09': {'edit_count': 1,
#   'sentiment': -0.9989689588546753,
#   'neg_sentiment': 1.0},
#  '2011-10-10': {'edit_count': 1,
#   'sentiment': 0.9482848048210144,
#   'neg_sentiment': 0.0},
#  '2011-10-11': {'edit_count': 1,
#   'sentiment': -0.9401983618736267,
#   'neg_sentiment': 1.0},
#  '2011-10-13': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-10-15': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2011-10-16': {'edit_count': 1,
#   'sentiment': -0.7848035097122192,
#   'neg_sentiment': 1.0},
#  '2011-10-17': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-10-18': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-10-19': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-10-20': {'edit_count': 1,
#   'sentiment': 0.9678489565849304,
#   'neg_sentiment': 0.0},
#  '2011-10-23': {'edit_count': 1,
#   'sentiment': -0.9974919557571411,
#   'neg_sentiment': 1.0},
#  '2011-10-24': {'edit_count': 1,
#   'sentiment': 0.6268858909606934,
#   'neg_sentiment': 0.0},
#  '2011-10-25': {'edit_count': 1,
#   'sentiment': -0.9472301602363586,
#   'neg_sentiment': 1.0},
#  '2011-10-27': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-10-28': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-10-30': {'edit_count': 1,
#   'sentiment': -0.9992759823799133,
#   'neg_sentiment': 1.0},
#  '2011-10-31': {'edit_count': 1,
#   'sentiment': -0.9982296824455261,
#   'neg_sentiment': 1.0},
#  '2011-11-01': {'edit_count': 1,
#   'sentiment': -0.997133731842041,
#   'neg_sentiment': 1.0},
#  '2011-11-03': {'edit_count': 1,
#   'sentiment': 0.9598671197891235,
#   'neg_sentiment': 0.0},
#  '2011-11-04': {'edit_count': 1,
#   'sentiment': -0.9993987083435059,
#   'neg_sentiment': 1.0},
#  '2011-11-05': {'edit_count': 1,
#   'sentiment': -0.9985162615776062,
#   'neg_sentiment': 1.0},
#  '2011-11-06': {'edit_count': 1,
#   'sentiment': -0.8195271492004395,
#   'neg_sentiment': 1.0},
#  '2011-11-12': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-11-13': {'edit_count': 1,
#   'sentiment': -0.9972186088562012,
#   'neg_sentiment': 1.0},
#  '2011-11-14': {'edit_count': 1,
#   'sentiment': -0.9982510209083557,
#   'neg_sentiment': 1.0},
#  '2011-11-15': {'edit_count': 1,
#   'sentiment': -0.9911885261535645,
#   'neg_sentiment': 1.0},
#  '2011-11-18': {'edit_count': 1,
#   'sentiment': -0.9997937083244324,
#   'neg_sentiment': 1.0},
#  '2011-11-20': {'edit_count': 1,
#   'sentiment': 0.7705317139625549,
#   'neg_sentiment': 0.0},
#  '2011-11-21': {'edit_count': 1,
#   'sentiment': 0.9894212484359741,
#   'neg_sentiment': 0.0},
#  '2011-11-22': {'edit_count': 1,
#   'sentiment': -0.9989380240440369,
#   'neg_sentiment': 1.0},
#  '2011-11-23': {'edit_count': 1,
#   'sentiment': -0.9409189820289612,
#   'neg_sentiment': 1.0},
#  '2011-11-25': {'edit_count': 1,
#   'sentiment': -0.9974541068077087,
#   'neg_sentiment': 1.0},
#  '2011-11-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-11-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-11-28': {'edit_count': 1,
#   'sentiment': -0.9875800013542175,
#   'neg_sentiment': 1.0},
#  '2011-11-29': {'edit_count': 1,
#   'sentiment': -0.9891662001609802,
#   'neg_sentiment': 1.0},
#  '2011-11-30': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2011-12-01': {'edit_count': 1,
#   'sentiment': -0.9960261583328247,
#   'neg_sentiment': 1.0},
#  '2011-12-02': {'edit_count': 1,
#   'sentiment': -0.9950590133666992,
#   'neg_sentiment': 1.0},
#  '2011-12-04': {'edit_count': 1,
#   'sentiment': -0.9997431635856628,
#   'neg_sentiment': 1.0},
#  '2011-12-05': {'edit_count': 1,
#   'sentiment': -0.9980335831642151,
#   'neg_sentiment': 1.0},
#  '2011-12-06': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2011-12-07': {'edit_count': 1,
#   'sentiment': 0.9423258304595947,
#   'neg_sentiment': 0.0},
#  '2011-12-09': {'edit_count': 1,
#   'sentiment': -0.9990200996398926,
#   'neg_sentiment': 1.0},
#  '2011-12-10': {'edit_count': 1,
#   'sentiment': -0.6650756001472473,
#   'neg_sentiment': 1.0},
#  '2011-12-12': {'edit_count': 1,
#   'sentiment': -0.8184987902641296,
#   'neg_sentiment': 1.0},
#  '2011-12-13': {'edit_count': 1,
#   'sentiment': -0.7921819686889648,
#   'neg_sentiment': 1.0},
#  '2011-12-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-12-17': {'edit_count': 1,
#   'sentiment': -0.9993336796760559,
#   'neg_sentiment': 1.0},
#  '2011-12-18': {'edit_count': 1,
#   'sentiment': -0.6610729694366455,
#   'neg_sentiment': 1.0},
#  '2011-12-20': {'edit_count': 1,
#   'sentiment': -0.9998160004615784,
#   'neg_sentiment': 1.0},
#  '2011-12-21': {'edit_count': 1,
#   'sentiment': -0.7921819686889648,
#   'neg_sentiment': 1.0},
#  '2011-12-22': {'edit_count': 1,
#   'sentiment': -0.8130702972412109,
#   'neg_sentiment': 1.0},
#  '2011-12-23': {'edit_count': 1,
#   'sentiment': -0.9966468214988708,
#   'neg_sentiment': 1.0},
#  '2011-12-24': {'edit_count': 1,
#   'sentiment': 0.9518777132034302,
#   'neg_sentiment': 0.0},
#  '2011-12-25': {'edit_count': 1,
#   'sentiment': -0.9957411289215088,
#   'neg_sentiment': 1.0},
#  '2011-12-26': {'edit_count': 1,
#   'sentiment': 0.9945512413978577,
#   'neg_sentiment': 0.0},
#  '2011-12-28': {'edit_count': 1,
#   'sentiment': -0.9964214563369751,
#   'neg_sentiment': 1.0},
#  '2011-12-29': {'edit_count': 1,
#   'sentiment': -0.9993988275527954,
#   'neg_sentiment': 1.0},
#  '2011-12-31': {'edit_count': 1,
#   'sentiment': 0.9884890913963318,
#   'neg_sentiment': 0.0},
#  '2012-01-01': {'edit_count': 1,
#   'sentiment': -0.9986787438392639,
#   'neg_sentiment': 1.0},
#  '2012-01-03': {'edit_count': 1,
#   'sentiment': -0.686349093914032,
#   'neg_sentiment': 1.0},
#  '2012-01-04': {'edit_count': 1,
#   'sentiment': 0.7485930323600769,
#   'neg_sentiment': 0.0},
#  '2012-01-05': {'edit_count': 1,
#   'sentiment': 0.6554882526397705,
#   'neg_sentiment': 0.0},
#  '2012-01-08': {'edit_count': 1,
#   'sentiment': 0.7407242059707642,
#   'neg_sentiment': 0.0},
#  '2012-01-09': {'edit_count': 1,
#   'sentiment': -0.9970996379852295,
#   'neg_sentiment': 1.0},
#  '2012-01-10': {'edit_count': 1,
#   'sentiment': -0.9975322484970093,
#   'neg_sentiment': 1.0},
#  '2012-01-12': {'edit_count': 1,
#   'sentiment': -0.9492558240890503,
#   'neg_sentiment': 1.0},
#  '2012-01-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-01-16': {'edit_count': 1,
#   'sentiment': 0.9936368465423584,
#   'neg_sentiment': 0.0},
#  '2012-01-17': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2012-01-19': {'edit_count': 1,
#   'sentiment': -0.9766056537628174,
#   'neg_sentiment': 1.0},
#  '2012-01-21': {'edit_count': 1,
#   'sentiment': 0.9998354911804199,
#   'neg_sentiment': 0.0},
#  '2012-01-22': {'edit_count': 1,
#   'sentiment': -0.985650360584259,
#   'neg_sentiment': 1.0},
#  '2012-01-24': {'edit_count': 1,
#   'sentiment': -0.9859530925750732,
#   'neg_sentiment': 1.0},
#  '2012-01-26': {'edit_count': 1,
#   'sentiment': -0.9413517713546753,
#   'neg_sentiment': 1.0},
#  '2012-01-28': {'edit_count': 1,
#   'sentiment': -0.9982331991195679,
#   'neg_sentiment': 1.0},
#  '2012-02-01': {'edit_count': 1,
#   'sentiment': -0.8897268176078796,
#   'neg_sentiment': 1.0},
#  '2012-02-03': {'edit_count': 1,
#   'sentiment': 0.5884552597999573,
#   'neg_sentiment': 0.0},
#  '2012-02-05': {'edit_count': 1,
#   'sentiment': -0.9974821209907532,
#   'neg_sentiment': 1.0},
#  '2012-02-07': {'edit_count': 1,
#   'sentiment': 0.9997379183769226,
#   'neg_sentiment': 0.0},
#  '2012-02-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-02-09': {'edit_count': 1,
#   'sentiment': -0.9988163709640503,
#   'neg_sentiment': 1.0},
#  '2012-02-11': {'edit_count': 1,
#   'sentiment': -0.997818112373352,
#   'neg_sentiment': 1.0},
#  '2012-02-12': {'edit_count': 1,
#   'sentiment': 0.9993176460266113,
#   'neg_sentiment': 0.0},
#  '2012-02-13': {'edit_count': 1,
#   'sentiment': 0.9898702502250671,
#   'neg_sentiment': 0.0},
#  '2012-02-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-02-16': {'edit_count': 1,
#   'sentiment': 0.6930745840072632,
#   'neg_sentiment': 0.0},
#  '2012-02-17': {'edit_count': 1,
#   'sentiment': -0.9860801100730896,
#   'neg_sentiment': 1.0},
#  '2012-02-18': {'edit_count': 1,
#   'sentiment': -0.9932367205619812,
#   'neg_sentiment': 1.0},
#  '2012-02-19': {'edit_count': 1,
#   'sentiment': -0.996272087097168,
#   'neg_sentiment': 1.0},
#  '2012-02-20': {'edit_count': 1,
#   'sentiment': 0.6861263513565063,
#   'neg_sentiment': 0.0},
#  '2012-02-21': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-02-23': {'edit_count': 1,
#   'sentiment': -0.8757374882698059,
#   'neg_sentiment': 1.0},
#  '2012-02-24': {'edit_count': 1,
#   'sentiment': -0.9939278364181519,
#   'neg_sentiment': 1.0},
#  '2012-02-25': {'edit_count': 1,
#   'sentiment': -0.7921819686889648,
#   'neg_sentiment': 1.0},
#  '2012-02-28': {'edit_count': 1,
#   'sentiment': 0.9939460158348083,
#   'neg_sentiment': 0.0},
#  '2012-02-29': {'edit_count': 1,
#   'sentiment': -0.9983110427856445,
#   'neg_sentiment': 1.0},
#  '2012-03-01': {'edit_count': 1,
#   'sentiment': 0.7407242059707642,
#   'neg_sentiment': 0.0},
#  '2012-03-03': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2012-03-04': {'edit_count': 1,
#   'sentiment': 0.9271292686462402,
#   'neg_sentiment': 0.0},
#  '2012-03-05': {'edit_count': 1,
#   'sentiment': -0.9979900121688843,
#   'neg_sentiment': 1.0},
#  '2012-03-08': {'edit_count': 1,
#   'sentiment': -0.8906550407409668,
#   'neg_sentiment': 1.0},
#  '2012-03-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-03-11': {'edit_count': 1,
#   'sentiment': 0.9726091623306274,
#   'neg_sentiment': 0.0},
#  '2012-03-12': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-03-16': {'edit_count': 1,
#   'sentiment': 0.9692978262901306,
#   'neg_sentiment': 0.0},
#  '2012-03-17': {'edit_count': 1,
#   'sentiment': 0.9955694079399109,
#   'neg_sentiment': 0.0},
#  '2012-03-18': {'edit_count': 1,
#   'sentiment': -0.9996962547302246,
#   'neg_sentiment': 1.0},
#  '2012-03-19': {'edit_count': 1,
#   'sentiment': 0.9981939196586609,
#   'neg_sentiment': 0.0},
#  '2012-03-20': {'edit_count': 1,
#   'sentiment': 0.9981281161308289,
#   'neg_sentiment': 0.0},
#  '2012-03-21': {'edit_count': 1,
#   'sentiment': 0.9874131679534912,
#   'neg_sentiment': 0.0},
#  '2012-03-22': {'edit_count': 1,
#   'sentiment': -0.7921819686889648,
#   'neg_sentiment': 1.0},
#  '2012-03-23': {'edit_count': 1,
#   'sentiment': -0.9943137168884277,
#   'neg_sentiment': 1.0},
#  '2012-03-29': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2012-04-01': {'edit_count': 1,
#   'sentiment': -0.9996688365936279,
#   'neg_sentiment': 1.0},
#  '2012-04-02': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-04-03': {'edit_count': 1,
#   'sentiment': 0.9965303540229797,
#   'neg_sentiment': 0.0},
#  '2012-04-05': {'edit_count': 1,
#   'sentiment': -0.8697817325592041,
#   'neg_sentiment': 1.0},
#  '2012-04-06': {'edit_count': 1,
#   'sentiment': 0.9945301413536072,
#   'neg_sentiment': 0.0},
#  '2012-04-07': {'edit_count': 1,
#   'sentiment': -0.999650239944458,
#   'neg_sentiment': 1.0},
#  '2012-04-08': {'edit_count': 1,
#   'sentiment': -0.63308185338974,
#   'neg_sentiment': 1.0},
#  '2012-04-09': {'edit_count': 1,
#   'sentiment': -0.9961450099945068,
#   'neg_sentiment': 1.0},
#  '2012-04-10': {'edit_count': 1,
#   'sentiment': 0.8278048038482666,
#   'neg_sentiment': 0.0},
#  '2012-04-13': {'edit_count': 1,
#   'sentiment': -0.9695767164230347,
#   'neg_sentiment': 1.0},
#  '2012-04-15': {'edit_count': 1,
#   'sentiment': -0.9997593760490417,
#   'neg_sentiment': 1.0},
#  '2012-04-17': {'edit_count': 1,
#   'sentiment': -0.9953972697257996,
#   'neg_sentiment': 1.0},
#  '2012-04-18': {'edit_count': 1,
#   'sentiment': 0.9271292686462402,
#   'neg_sentiment': 0.0},
#  '2012-04-20': {'edit_count': 1,
#   'sentiment': -0.9608961343765259,
#   'neg_sentiment': 1.0},
#  '2012-04-23': {'edit_count': 1,
#   'sentiment': -0.983380913734436,
#   'neg_sentiment': 1.0},
#  '2012-04-24': {'edit_count': 1,
#   'sentiment': -0.9994528889656067,
#   'neg_sentiment': 1.0},
#  '2012-04-30': {'edit_count': 1,
#   'sentiment': 0.6861263513565063,
#   'neg_sentiment': 0.0},
#  '2012-05-02': {'edit_count': 1,
#   'sentiment': -0.9982331991195679,
#   'neg_sentiment': 1.0},
#  '2012-05-03': {'edit_count': 1,
#   'sentiment': -0.7921819686889648,
#   'neg_sentiment': 1.0},
#  '2012-05-04': {'edit_count': 1,
#   'sentiment': -0.993198573589325,
#   'neg_sentiment': 1.0},
#  '2012-05-06': {'edit_count': 1,
#   'sentiment': 0.6268858909606934,
#   'neg_sentiment': 0.0},
#  '2012-05-07': {'edit_count': 1,
#   'sentiment': 0.9637523889541626,
#   'neg_sentiment': 0.0},
#  '2012-05-12': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-05-15': {'edit_count': 1,
#   'sentiment': -0.9843831658363342,
#   'neg_sentiment': 1.0},
#  '2012-05-16': {'edit_count': 1,
#   'sentiment': -0.9989104270935059,
#   'neg_sentiment': 1.0},
#  '2012-05-17': {'edit_count': 1,
#   'sentiment': -0.9992491602897644,
#   'neg_sentiment': 1.0},
#  '2012-05-18': {'edit_count': 1,
#   'sentiment': 0.9902607798576355,
#   'neg_sentiment': 0.0},
#  '2012-05-21': {'edit_count': 1,
#   'sentiment': -0.9982331991195679,
#   'neg_sentiment': 1.0},
#  '2012-05-22': {'edit_count': 1,
#   'sentiment': -0.941938042640686,
#   'neg_sentiment': 1.0},
#  '2012-05-23': {'edit_count': 1,
#   'sentiment': 0.6268858909606934,
#   'neg_sentiment': 0.0},
#  '2012-05-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-05-26': {'edit_count': 1,
#   'sentiment': 0.8174483776092529,
#   'neg_sentiment': 0.0},
#  '2012-05-28': {'edit_count': 1,
#   'sentiment': 0.8174483776092529,
#   'neg_sentiment': 0.0},
#  '2012-05-30': {'edit_count': 1,
#   'sentiment': -0.9401583671569824,
#   'neg_sentiment': 1.0},
#  '2012-06-01': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-06-02': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2012-06-03': {'edit_count': 1,
#   'sentiment': -0.988905668258667,
#   'neg_sentiment': 1.0},
#  '2012-06-04': {'edit_count': 1,
#   'sentiment': -0.9981369972229004,
#   'neg_sentiment': 1.0},
#  '2012-06-05': {'edit_count': 1,
#   'sentiment': 0.937751293182373,
#   'neg_sentiment': 0.0},
#  '2012-06-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-06-09': {'edit_count': 1,
#   'sentiment': -0.9982489347457886,
#   'neg_sentiment': 1.0},
#  '2012-06-10': {'edit_count': 1,
#   'sentiment': -0.9993415474891663,
#   'neg_sentiment': 1.0},
#  '2012-06-11': {'edit_count': 1,
#   'sentiment': -0.9955434203147888,
#   'neg_sentiment': 1.0},
#  '2012-06-13': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2012-06-14': {'edit_count': 1,
#   'sentiment': -0.9148892760276794,
#   'neg_sentiment': 1.0},
#  '2012-06-15': {'edit_count': 1,
#   'sentiment': 0.9974367022514343,
#   'neg_sentiment': 0.0},
#  '2012-06-21': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-06-22': {'edit_count': 1,
#   'sentiment': 0.7485930323600769,
#   'neg_sentiment': 0.0},
#  '2012-06-24': {'edit_count': 1,
#   'sentiment': -0.9975455403327942,
#   'neg_sentiment': 1.0},
#  '2012-06-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-06-26': {'edit_count': 1,
#   'sentiment': -0.9438227415084839,
#   'neg_sentiment': 1.0},
#  '2012-06-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-06-28': {'edit_count': 1,
#   'sentiment': -0.9803495407104492,
#   'neg_sentiment': 1.0},
#  '2012-06-29': {'edit_count': 1,
#   'sentiment': -0.993515133857727,
#   'neg_sentiment': 1.0},
#  '2012-06-30': {'edit_count': 1,
#   'sentiment': -0.9993295669555664,
#   'neg_sentiment': 1.0},
#  '2012-07-01': {'edit_count': 1,
#   'sentiment': -0.9974602460861206,
#   'neg_sentiment': 1.0},
#  '2012-07-02': {'edit_count': 1,
#   'sentiment': -0.9996908903121948,
#   'neg_sentiment': 1.0},
#  '2012-07-03': {'edit_count': 1,
#   'sentiment': -0.9971132278442383,
#   'neg_sentiment': 1.0},
#  '2012-07-06': {'edit_count': 1,
#   'sentiment': -0.9982383251190186,
#   'neg_sentiment': 1.0},
#  '2012-07-07': {'edit_count': 1,
#   'sentiment': -0.99940025806427,
#   'neg_sentiment': 1.0},
#  '2012-07-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-07-10': {'edit_count': 1,
#   'sentiment': -0.9879418015480042,
#   'neg_sentiment': 1.0},
#  '2012-07-11': {'edit_count': 1,
#   'sentiment': -0.8584815859794617,
#   'neg_sentiment': 1.0},
#  '2012-07-12': {'edit_count': 1,
#   'sentiment': -0.7035779356956482,
#   'neg_sentiment': 1.0},
#  '2012-07-13': {'edit_count': 1,
#   'sentiment': -0.9632538557052612,
#   'neg_sentiment': 1.0},
#  '2012-07-16': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2012-07-18': {'edit_count': 1,
#   'sentiment': -0.8262905478477478,
#   'neg_sentiment': 1.0},
#  '2012-07-19': {'edit_count': 1,
#   'sentiment': 0.9482848048210144,
#   'neg_sentiment': 0.0},
#  '2012-07-20': {'edit_count': 1,
#   'sentiment': -0.974304735660553,
#   'neg_sentiment': 1.0},
#  '2012-07-21': {'edit_count': 1,
#   'sentiment': -0.9982331991195679,
#   'neg_sentiment': 1.0},
#  '2012-07-22': {'edit_count': 1,
#   'sentiment': -0.998062789440155,
#   'neg_sentiment': 1.0},
#  '2012-07-31': {'edit_count': 1,
#   'sentiment': -0.9738450646400452,
#   'neg_sentiment': 1.0},
#  '2012-08-01': {'edit_count': 1,
#   'sentiment': -0.9959985017776489,
#   'neg_sentiment': 1.0},
#  '2012-08-02': {'edit_count': 1,
#   'sentiment': 0.6268858909606934,
#   'neg_sentiment': 0.0},
#  '2012-08-03': {'edit_count': 1,
#   'sentiment': -0.9168182015419006,
#   'neg_sentiment': 1.0},
#  '2012-08-06': {'edit_count': 1,
#   'sentiment': 0.9914156794548035,
#   'neg_sentiment': 0.0},
#  '2012-08-07': {'edit_count': 1,
#   'sentiment': -0.999006450176239,
#   'neg_sentiment': 1.0},
#  '2012-08-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-08-10': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-08-13': {'edit_count': 1,
#   'sentiment': -0.99445641040802,
#   'neg_sentiment': 1.0},
#  '2012-08-14': {'edit_count': 1,
#   'sentiment': 0.6268858909606934,
#   'neg_sentiment': 0.0},
#  '2012-08-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-08-16': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-08-17': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2012-08-18': {'edit_count': 1,
#   'sentiment': -0.9977051615715027,
#   'neg_sentiment': 1.0},
#  '2012-08-19': {'edit_count': 1,
#   'sentiment': -0.9920401573181152,
#   'neg_sentiment': 1.0},
#  '2012-08-20': {'edit_count': 1,
#   'sentiment': -0.999669075012207,
#   'neg_sentiment': 1.0},
#  '2012-08-21': {'edit_count': 1,
#   'sentiment': -0.994763195514679,
#   'neg_sentiment': 1.0},
#  '2012-08-22': {'edit_count': 1,
#   'sentiment': -0.6209489107131958,
#   'neg_sentiment': 1.0},
#  '2012-08-23': {'edit_count': 1,
#   'sentiment': -0.9925693869590759,
#   'neg_sentiment': 1.0},
#  '2012-08-24': {'edit_count': 1,
#   'sentiment': -0.7921819686889648,
#   'neg_sentiment': 1.0},
#  '2012-08-27': {'edit_count': 1,
#   'sentiment': -0.5460423827171326,
#   'neg_sentiment': 1.0},
#  '2012-08-28': {'edit_count': 1,
#   'sentiment': -0.9996695518493652,
#   'neg_sentiment': 1.0},
#  '2012-08-29': {'edit_count': 1,
#   'sentiment': 0.9962038397789001,
#   'neg_sentiment': 0.0},
#  '2012-08-31': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-09-02': {'edit_count': 1,
#   'sentiment': -0.9986044764518738,
#   'neg_sentiment': 1.0},
#  '2012-09-03': {'edit_count': 1,
#   'sentiment': -0.8441582322120667,
#   'neg_sentiment': 1.0},
#  '2012-09-05': {'edit_count': 1,
#   'sentiment': -0.9677581787109375,
#   'neg_sentiment': 1.0},
#  '2012-09-06': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2012-09-07': {'edit_count': 1,
#   'sentiment': 0.9349585771560669,
#   'neg_sentiment': 0.0},
#  '2012-09-08': {'edit_count': 1,
#   'sentiment': -0.9360693693161011,
#   'neg_sentiment': 1.0},
#  '2012-09-09': {'edit_count': 1,
#   'sentiment': 0.9511266350746155,
#   'neg_sentiment': 0.0},
#  '2012-09-10': {'edit_count': 1,
#   'sentiment': -0.9997852444648743,
#   'neg_sentiment': 1.0},
#  '2012-09-11': {'edit_count': 1,
#   'sentiment': -0.9941723942756653,
#   'neg_sentiment': 1.0},
#  '2012-09-12': {'edit_count': 1,
#   'sentiment': -0.9997848868370056,
#   'neg_sentiment': 1.0},
#  '2012-09-13': {'edit_count': 1,
# ...
#   'neg_sentiment': 1.0},
#  '2013-12-28': {'edit_count': 1,
#   'sentiment': -0.9645002484321594,
#   'neg_sentiment': 1.0},
#  '2013-12-29': {'edit_count': 1,
#   'sentiment': -0.9990197420120239,
#   'neg_sentiment': 1.0},
#  '2013-12-30': {'edit_count': 1,
#   'sentiment': 0.8748215436935425,
#   'neg_sentiment': 0.0},
#  '2013-12-31': {'edit_count': 1,
#   'sentiment': -0.9611033201217651,
#   'neg_sentiment': 1.0},
#  '2014-01-01': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-01-02': {'edit_count': 1,
#   'sentiment': -0.997840404510498,
#   'neg_sentiment': 1.0},
#  '2014-01-03': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-01-04': {'edit_count': 1,
#   'sentiment': -0.9923862218856812,
#   'neg_sentiment': 1.0},
#  '2014-01-05': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-01-06': {'edit_count': 1,
#   'sentiment': -0.9948531985282898,
#   'neg_sentiment': 1.0},
#  '2014-01-07': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2014-01-08': {'edit_count': 1,
#   'sentiment': -0.9959009289741516,
#   'neg_sentiment': 1.0},
#  '2014-01-09': {'edit_count': 1,
#   'sentiment': -0.9965474009513855,
#   'neg_sentiment': 1.0},
#  '2014-01-10': {'edit_count': 1,
#   'sentiment': -0.9655764698982239,
#   'neg_sentiment': 1.0},
#  '2014-01-11': {'edit_count': 1,
#   'sentiment': 0.9642006158828735,
#   'neg_sentiment': 0.0},
#  '2014-01-12': {'edit_count': 1,
#   'sentiment': 0.9975378513336182,
#   'neg_sentiment': 0.0},
#  '2014-01-13': {'edit_count': 1,
#   'sentiment': -0.9893931150436401,
#   'neg_sentiment': 1.0},
#  '2014-01-14': {'edit_count': 1,
#   'sentiment': -0.99483722448349,
#   'neg_sentiment': 1.0},
#  '2014-01-15': {'edit_count': 1,
#   'sentiment': -0.9970608353614807,
#   'neg_sentiment': 1.0},
#  '2014-01-16': {'edit_count': 1,
#   'sentiment': 0.9997019171714783,
#   'neg_sentiment': 0.0},
#  '2014-01-17': {'edit_count': 1,
#   'sentiment': 0.9082411527633667,
#   'neg_sentiment': 0.0},
#  '2014-01-18': {'edit_count': 1,
#   'sentiment': -0.9991075396537781,
#   'neg_sentiment': 1.0},
#  '2014-01-19': {'edit_count': 1,
#   'sentiment': -0.9936423301696777,
#   'neg_sentiment': 1.0},
#  '2014-01-20': {'edit_count': 1,
#   'sentiment': -0.9991008043289185,
#   'neg_sentiment': 1.0},
#  '2014-01-21': {'edit_count': 1,
#   'sentiment': 0.8901327252388,
#   'neg_sentiment': 0.0},
#  '2014-01-22': {'edit_count': 1,
#   'sentiment': -0.8440172672271729,
#   'neg_sentiment': 1.0},
#  '2014-01-23': {'edit_count': 1,
#   'sentiment': 0.6905444860458374,
#   'neg_sentiment': 0.0},
#  '2014-01-24': {'edit_count': 1,
#   'sentiment': -0.8761953115463257,
#   'neg_sentiment': 1.0},
#  '2014-01-25': {'edit_count': 1,
#   'sentiment': 0.9757413864135742,
#   'neg_sentiment': 0.0},
#  '2014-01-26': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2014-01-27': {'edit_count': 1,
#   'sentiment': 0.982856810092926,
#   'neg_sentiment': 0.0},
#  '2014-01-28': {'edit_count': 1,
#   'sentiment': 0.9745295643806458,
#   'neg_sentiment': 0.0},
#  '2014-01-29': {'edit_count': 1,
#   'sentiment': -0.999681830406189,
#   'neg_sentiment': 1.0},
#  '2014-01-30': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-01-31': {'edit_count': 1,
#   'sentiment': 0.95038902759552,
#   'neg_sentiment': 0.0},
#  '2014-02-01': {'edit_count': 1,
#   'sentiment': -0.9566238522529602,
#   'neg_sentiment': 1.0},
#  '2014-02-02': {'edit_count': 1,
#   'sentiment': -0.9607056379318237,
#   'neg_sentiment': 1.0},
#  '2014-02-03': {'edit_count': 1,
#   'sentiment': 0.9135410189628601,
#   'neg_sentiment': 0.0},
#  '2014-02-04': {'edit_count': 1,
#   'sentiment': 0.98163902759552,
#   'neg_sentiment': 0.0},
#  '2014-02-05': {'edit_count': 1,
#   'sentiment': 0.9686891436576843,
#   'neg_sentiment': 0.0},
#  '2014-02-06': {'edit_count': 1,
#   'sentiment': 0.9406096339225769,
#   'neg_sentiment': 0.0},
#  '2014-02-07': {'edit_count': 1,
#   'sentiment': -0.9764832258224487,
#   'neg_sentiment': 1.0},
#  '2014-02-08': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2014-02-09': {'edit_count': 1,
#   'sentiment': -0.9222768545150757,
#   'neg_sentiment': 1.0},
#  '2014-02-10': {'edit_count': 1,
#   'sentiment': -0.6098253726959229,
#   'neg_sentiment': 1.0},
#  '2014-02-11': {'edit_count': 1,
#   'sentiment': -0.9837419986724854,
#   'neg_sentiment': 1.0},
#  '2014-02-12': {'edit_count': 1,
#   'sentiment': -0.9904325604438782,
#   'neg_sentiment': 1.0},
#  '2014-02-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-02-14': {'edit_count': 1,
#   'sentiment': -0.9998030066490173,
#   'neg_sentiment': 1.0},
#  '2014-02-15': {'edit_count': 1,
#   'sentiment': -0.9940272569656372,
#   'neg_sentiment': 1.0},
#  '2014-02-16': {'edit_count': 1,
#   'sentiment': -0.9992122650146484,
#   'neg_sentiment': 1.0},
#  '2014-02-17': {'edit_count': 1,
#   'sentiment': -0.9971330165863037,
#   'neg_sentiment': 1.0},
#  '2014-02-19': {'edit_count': 1,
#   'sentiment': 0.957493782043457,
#   'neg_sentiment': 0.0},
#  '2014-02-21': {'edit_count': 1,
#   'sentiment': -0.9995903372764587,
#   'neg_sentiment': 1.0},
#  '2014-02-22': {'edit_count': 1,
#   'sentiment': 0.9708603024482727,
#   'neg_sentiment': 0.0},
#  '2014-02-23': {'edit_count': 1,
#   'sentiment': -0.9707514643669128,
#   'neg_sentiment': 1.0},
#  '2014-02-24': {'edit_count': 1,
#   'sentiment': -0.9905113577842712,
#   'neg_sentiment': 1.0},
#  '2014-02-25': {'edit_count': 1,
#   'sentiment': -0.9310159087181091,
#   'neg_sentiment': 1.0},
#  '2014-02-26': {'edit_count': 1,
#   'sentiment': -0.9970249533653259,
#   'neg_sentiment': 1.0},
#  '2014-02-27': {'edit_count': 1,
#   'sentiment': -0.9987523555755615,
#   'neg_sentiment': 1.0},
#  '2014-02-28': {'edit_count': 1,
#   'sentiment': -0.9880879521369934,
#   'neg_sentiment': 1.0},
#  '2014-03-01': {'edit_count': 1,
#   'sentiment': -0.9997159838676453,
#   'neg_sentiment': 1.0},
#  '2014-03-02': {'edit_count': 1,
#   'sentiment': -0.9950957298278809,
#   'neg_sentiment': 1.0},
#  '2014-03-03': {'edit_count': 1,
#   'sentiment': -0.9989383816719055,
#   'neg_sentiment': 1.0},
#  '2014-03-04': {'edit_count': 1,
#   'sentiment': 0.9994150400161743,
#   'neg_sentiment': 0.0},
#  '2014-03-05': {'edit_count': 1,
#   'sentiment': -0.9877682328224182,
#   'neg_sentiment': 1.0},
#  '2014-03-06': {'edit_count': 1,
#   'sentiment': -0.9601902365684509,
#   'neg_sentiment': 1.0},
#  '2014-03-07': {'edit_count': 1,
#   'sentiment': -0.9975162744522095,
#   'neg_sentiment': 1.0},
#  '2014-03-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-03-09': {'edit_count': 1,
#   'sentiment': -0.998859167098999,
#   'neg_sentiment': 1.0},
#  '2014-03-10': {'edit_count': 1,
#   'sentiment': -0.9278894662857056,
#   'neg_sentiment': 1.0},
#  '2014-03-11': {'edit_count': 1,
#   'sentiment': -0.9927685260772705,
#   'neg_sentiment': 1.0},
#  '2014-03-12': {'edit_count': 1,
#   'sentiment': -0.9994435906410217,
#   'neg_sentiment': 1.0},
#  '2014-03-13': {'edit_count': 1,
#   'sentiment': -0.7991572022438049,
#   'neg_sentiment': 1.0},
#  '2014-03-14': {'edit_count': 1,
#   'sentiment': -0.9983341097831726,
#   'neg_sentiment': 1.0},
#  '2014-03-15': {'edit_count': 1,
#   'sentiment': 0.6617141366004944,
#   'neg_sentiment': 0.0},
#  '2014-03-16': {'edit_count': 1,
#   'sentiment': -0.9995993971824646,
#   'neg_sentiment': 1.0},
#  '2014-03-17': {'edit_count': 1,
#   'sentiment': 0.7327306270599365,
#   'neg_sentiment': 0.0},
#  '2014-03-18': {'edit_count': 1,
#   'sentiment': -0.9806907773017883,
#   'neg_sentiment': 1.0},
#  '2014-03-19': {'edit_count': 1,
#   'sentiment': -0.9989854693412781,
#   'neg_sentiment': 1.0},
#  '2014-03-20': {'edit_count': 1,
#   'sentiment': -0.9969342947006226,
#   'neg_sentiment': 1.0},
#  '2014-03-21': {'edit_count': 1,
#   'sentiment': -0.9986816048622131,
#   'neg_sentiment': 1.0},
#  '2014-03-22': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-03-23': {'edit_count': 1,
#   'sentiment': -0.9895713329315186,
#   'neg_sentiment': 1.0},
#  '2014-03-24': {'edit_count': 1,
#   'sentiment': -0.9668273329734802,
#   'neg_sentiment': 1.0},
#  '2014-03-25': {'edit_count': 1,
#   'sentiment': 0.9987602233886719,
#   'neg_sentiment': 0.0},
#  '2014-03-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-03-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-03-28': {'edit_count': 1,
#   'sentiment': -0.9950078725814819,
#   'neg_sentiment': 1.0},
#  '2014-03-29': {'edit_count': 1,
#   'sentiment': -0.9968582391738892,
#   'neg_sentiment': 1.0},
#  '2014-03-30': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-03-31': {'edit_count': 1,
#   'sentiment': -0.9902201294898987,
#   'neg_sentiment': 1.0},
#  '2014-04-01': {'edit_count': 1,
#   'sentiment': -0.9774152636528015,
#   'neg_sentiment': 1.0},
#  '2014-04-02': {'edit_count': 1,
#   'sentiment': -0.9943569302558899,
#   'neg_sentiment': 1.0},
#  '2014-04-03': {'edit_count': 1,
#   'sentiment': -0.995644211769104,
#   'neg_sentiment': 1.0},
#  '2014-04-04': {'edit_count': 1,
#   'sentiment': 0.9789515137672424,
#   'neg_sentiment': 0.0},
#  '2014-04-05': {'edit_count': 1,
#   'sentiment': -0.9993261098861694,
#   'neg_sentiment': 1.0},
#  '2014-04-06': {'edit_count': 1,
#   'sentiment': -0.9802908897399902,
#   'neg_sentiment': 1.0},
#  '2014-04-07': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2014-04-08': {'edit_count': 1,
#   'sentiment': 0.986111044883728,
#   'neg_sentiment': 0.0},
#  '2014-04-09': {'edit_count': 1,
#   'sentiment': 0.798187792301178,
#   'neg_sentiment': 0.0},
#  '2014-04-10': {'edit_count': 1,
#   'sentiment': -0.9993027448654175,
#   'neg_sentiment': 1.0},
#  '2014-04-11': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-04-12': {'edit_count': 1,
#   'sentiment': -0.9771127700805664,
#   'neg_sentiment': 1.0},
#  '2014-04-13': {'edit_count': 1,
#   'sentiment': -0.9690285921096802,
#   'neg_sentiment': 1.0},
#  '2014-04-14': {'edit_count': 1,
#   'sentiment': -0.999276340007782,
#   'neg_sentiment': 1.0},
#  '2014-04-15': {'edit_count': 1,
#   'sentiment': 0.9691081643104553,
#   'neg_sentiment': 0.0},
#  '2014-04-16': {'edit_count': 1,
#   'sentiment': -0.9968041181564331,
#   'neg_sentiment': 1.0},
#  '2014-04-17': {'edit_count': 1,
#   'sentiment': -0.9776937961578369,
#   'neg_sentiment': 1.0},
#  '2014-04-18': {'edit_count': 1,
#   'sentiment': 0.859813392162323,
#   'neg_sentiment': 0.0},
#  '2014-04-19': {'edit_count': 1,
#   'sentiment': -0.9971113204956055,
#   'neg_sentiment': 1.0},
#  '2014-04-20': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-04-21': {'edit_count': 1,
#   'sentiment': -0.9215125441551208,
#   'neg_sentiment': 1.0},
#  '2014-04-22': {'edit_count': 1,
#   'sentiment': 0.9975547194480896,
#   'neg_sentiment': 0.0},
#  '2014-04-23': {'edit_count': 1,
#   'sentiment': -0.543174147605896,
#   'neg_sentiment': 1.0},
#  '2014-04-24': {'edit_count': 1,
#   'sentiment': -0.9993577599525452,
#   'neg_sentiment': 1.0},
#  '2014-04-25': {'edit_count': 1,
#   'sentiment': -0.9879717230796814,
#   'neg_sentiment': 1.0},
#  '2014-04-26': {'edit_count': 1,
#   'sentiment': -0.9819437265396118,
#   'neg_sentiment': 1.0},
#  '2014-04-27': {'edit_count': 1,
#   'sentiment': -0.9943643808364868,
#   'neg_sentiment': 1.0},
#  '2014-04-28': {'edit_count': 1,
#   'sentiment': -0.9991312623023987,
#   'neg_sentiment': 1.0},
#  '2014-04-29': {'edit_count': 1,
#   'sentiment': -0.9991264939308167,
#   'neg_sentiment': 1.0},
#  '2014-04-30': {'edit_count': 1,
#   'sentiment': -0.996650755405426,
#   'neg_sentiment': 1.0},
#  '2014-05-01': {'edit_count': 1,
#   'sentiment': -0.9985377788543701,
#   'neg_sentiment': 1.0},
#  '2014-05-02': {'edit_count': 1,
#   'sentiment': -0.999099612236023,
#   'neg_sentiment': 1.0},
#  '2014-05-04': {'edit_count': 1,
#   'sentiment': -0.9882262349128723,
#   'neg_sentiment': 1.0},
#  '2014-05-05': {'edit_count': 1,
#   'sentiment': -0.9898728132247925,
#   'neg_sentiment': 1.0},
#  '2014-05-06': {'edit_count': 1,
#   'sentiment': -0.9817251563072205,
#   'neg_sentiment': 1.0},
#  '2014-05-07': {'edit_count': 1,
#   'sentiment': -0.9973817467689514,
#   'neg_sentiment': 1.0},
#  '2014-05-08': {'edit_count': 1,
#   'sentiment': 0.9974859952926636,
#   'neg_sentiment': 0.0},
#  '2014-05-09': {'edit_count': 1,
#   'sentiment': -0.9995930790901184,
#   'neg_sentiment': 1.0},
#  '2014-05-10': {'edit_count': 1,
#   'sentiment': -0.9792113304138184,
#   'neg_sentiment': 1.0},
#  '2014-05-11': {'edit_count': 1,
#   'sentiment': -0.9996349811553955,
#   'neg_sentiment': 1.0},
#  '2014-05-12': {'edit_count': 1,
#   'sentiment': -0.9996414184570312,
#   'neg_sentiment': 1.0},
#  '2014-05-13': {'edit_count': 1,
#   'sentiment': -0.8816338181495667,
#   'neg_sentiment': 1.0},
#  '2014-05-14': {'edit_count': 1,
#   'sentiment': -0.9958192110061646,
#   'neg_sentiment': 1.0},
#  '2014-05-15': {'edit_count': 1,
#   'sentiment': -0.9771127700805664,
#   'neg_sentiment': 1.0},
#  '2014-05-16': {'edit_count': 1,
#   'sentiment': 0.9691081643104553,
#   'neg_sentiment': 0.0},
#  '2014-05-17': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-05-18': {'edit_count': 1,
#   'sentiment': -0.9713587164878845,
#   'neg_sentiment': 1.0},
#  '2014-05-19': {'edit_count': 1,
#   'sentiment': 0.9562854766845703,
#   'neg_sentiment': 0.0},
#  '2014-05-20': {'edit_count': 1,
#   'sentiment': -0.9978997707366943,
#   'neg_sentiment': 1.0},
#  '2014-05-21': {'edit_count': 1,
#   'sentiment': -0.9978686571121216,
#   'neg_sentiment': 1.0},
#  '2014-05-25': {'edit_count': 1,
#   'sentiment': -0.9952160120010376,
#   'neg_sentiment': 1.0},
#  '2014-05-26': {'edit_count': 1,
#   'sentiment': -0.9662109613418579,
#   'neg_sentiment': 1.0},
#  '2014-05-27': {'edit_count': 1,
#   'sentiment': -0.987871527671814,
#   'neg_sentiment': 1.0},
#  '2014-05-29': {'edit_count': 1,
#   'sentiment': -0.9753784537315369,
#   'neg_sentiment': 1.0},
#  '2014-05-30': {'edit_count': 1,
#   'sentiment': -0.9996479749679565,
#   'neg_sentiment': 1.0},
#  '2014-05-31': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2014-06-01': {'edit_count': 1,
#   'sentiment': -0.9981106519699097,
#   'neg_sentiment': 1.0},
#  '2014-06-02': {'edit_count': 1,
#   'sentiment': 0.9452303051948547,
#   'neg_sentiment': 0.0},
#  '2014-06-03': {'edit_count': 1,
#   'sentiment': -0.9996479749679565,
#   'neg_sentiment': 1.0},
#  '2014-06-04': {'edit_count': 1,
#   'sentiment': -0.9992285966873169,
#   'neg_sentiment': 1.0},
#  '2014-06-06': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-06-07': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2014-06-08': {'edit_count': 1,
#   'sentiment': -0.9970859885215759,
#   'neg_sentiment': 1.0},
#  '2014-06-09': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2014-06-10': {'edit_count': 1,
#   'sentiment': 0.872180163860321,
#   'neg_sentiment': 0.0},
#  '2014-06-11': {'edit_count': 1,
#   'sentiment': -0.9991532564163208,
#   'neg_sentiment': 1.0},
#  '2014-06-12': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-06-13': {'edit_count': 1,
#   'sentiment': 0.6168155074119568,
#   'neg_sentiment': 0.0},
#  '2014-06-15': {'edit_count': 1,
#   'sentiment': -0.9913254380226135,
#   'neg_sentiment': 1.0},
#  '2014-06-16': {'edit_count': 1,
#   'sentiment': 0.7185572385787964,
#   'neg_sentiment': 0.0},
#  '2014-06-17': {'edit_count': 1,
#   'sentiment': 0.930020809173584,
#   'neg_sentiment': 0.0},
#  '2014-06-18': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-06-19': {'edit_count': 1,
#   'sentiment': -0.9971330165863037,
#   'neg_sentiment': 1.0},
#  '2014-06-20': {'edit_count': 1,
#   'sentiment': -0.9192017912864685,
#   'neg_sentiment': 1.0},
#  '2014-06-21': {'edit_count': 1,
#   'sentiment': -0.9982319474220276,
#   'neg_sentiment': 1.0},
#  '2014-06-23': {'edit_count': 1,
#   'sentiment': -0.9704645276069641,
#   'neg_sentiment': 1.0},
#  '2014-06-24': {'edit_count': 1,
#   'sentiment': -0.9718877673149109,
#   'neg_sentiment': 1.0},
#  '2014-06-25': {'edit_count': 1,
#   'sentiment': -0.9990149736404419,
#   'neg_sentiment': 1.0},
#  '2014-06-26': {'edit_count': 1,
#   'sentiment': 0.9837321639060974,
#   'neg_sentiment': 0.0},
#  ...}

# %%
import pandas as pd
edits_df = pd.DataFrame.from_dict(edits, orient="index")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
edits_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             edit_count  sentiment  neg_sentiment
# 2009-03-08           1  -0.990592            1.0
# 2009-08-05           1   0.748121            0.0
# 2009-08-06           1   0.995746            0.0
# 2009-08-14           1   0.930021            0.0
# 2009-10-13           1   0.540435            0.0
# ...                ...        ...            ...
# 2023-06-15           1  -0.998935            1.0
# 2023-06-16           1  -0.999329            1.0
# 2023-06-24           1   0.998742            0.0
# 2023-06-27           1  -0.994694            1.0
# 2023-07-18           1  -0.999563            1.0
#
# [2607 rows x 3 columns]

# %%
edits_df.index = pd.to_datetime(edits_df.index)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from datetime import datetime
dates = pd.date_range(start="2009-03-08", end=datetime.today())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
edits_df = edits_df.reindex(dates, fill_value=0)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
edits_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             edit_count  sentiment  neg_sentiment
# 2009-03-08           1  -0.990592            1.0
# 2009-03-09           0   0.000000            0.0
# 2009-03-10           0   0.000000            0.0
# 2009-03-11           0   0.000000            0.0
# 2009-03-12           0   0.000000            0.0
# ...                ...        ...            ...
# 2023-07-17           0   0.000000            0.0
# 2023-07-18           1  -0.999563            1.0
# 2023-07-19           0   0.000000            0.0
# 2023-07-20           0   0.000000            0.0
# 2023-07-21           0   0.000000            0.0
#
# [5249 rows x 3 columns]

# %%
rolling_edits = edits_df.rolling(30, min_periods=30).mean()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rolling_edits = rolling_edits.dropna()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rolling_edits
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             edit_count  sentiment  neg_sentiment
# 2009-04-06    0.033333  -0.033020       0.033333
# 2009-04-07    0.000000   0.000000       0.000000
# 2009-04-08    0.000000   0.000000       0.000000
# 2009-04-09    0.000000   0.000000       0.000000
# 2009-04-10    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2023-07-17    0.066667   0.000135       0.033333
# 2023-07-18    0.100000  -0.033184       0.066667
# 2023-07-19    0.100000  -0.033184       0.066667
# 2023-07-20    0.100000  -0.033184       0.066667
# 2023-07-21    0.100000  -0.033184       0.066667
#
# [5220 rows x 3 columns]

# %%
rolling_edits.to_csv("wikipedia_edits.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import yfinance as yf
import os
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc_ticker = yf.Ticker("BTC-USD")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc = btc_ticker.history(period="max")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc =  btc.tz_localize(None)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-07-16  30297.472656  30437.560547  30089.669922  30249.132812
# 2023-07-17  30249.626953  30336.400391  29685.783203  30145.888672
# 2023-07-18  30147.070312  30233.656250  29556.427734  29856.562500
# 2023-07-19  29862.046875  30184.181641  29794.269531  29913.923828
# 2023-07-21  29803.185547  29940.945312  29741.357422  29782.476562
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800        0.0           0.0
# 2014-09-18     34483200        0.0           0.0
# 2014-09-19     37919700        0.0           0.0
# 2014-09-20     36863600        0.0           0.0
# 2014-09-21     26580100        0.0           0.0
# ...                 ...        ...           ...
# 2023-07-16   8516564470        0.0           0.0
# 2023-07-17  13240156074        0.0           0.0
# 2023-07-18  13138897269        0.0           0.0
# 2023-07-19  12128602812        0.0           0.0
# 2023-07-21  14650397696        0.0           0.0
#
# [3229 rows x 7 columns]

# %%
btc.index = pd.to_datetime(btc.index)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
del btc["Dividends"]
del btc["Stock Splits"]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc.columns = [c.lower() for c in btc.columns]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc.plot.line(y="close", use_index=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: xlabel='Date'>

# %%
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0, parse_dates=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
wiki
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             edit_count  sentiment  neg_sentiment
# 2009-04-06    0.033333  -0.033020       0.033333
# 2009-04-07    0.000000   0.000000       0.000000
# 2009-04-08    0.000000   0.000000       0.000000
# 2009-04-09    0.000000   0.000000       0.000000
# 2009-04-10    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2023-07-17    0.066667   0.000135       0.033333
# 2023-07-18    0.100000  -0.033184       0.066667
# 2023-07-19    0.100000  -0.033184       0.066667
# 2023-07-20    0.100000  -0.033184       0.066667
# 2023-07-21    0.100000  -0.033184       0.066667
#
# [5220 rows x 3 columns]

# %%
btc = btc.merge(wiki, left_index=True, right_index=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc["tomorrow"] = btc["close"].shift(-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc["target"] = (btc["tomorrow"] > btc["close"]).astype(int)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
btc["target"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 1    1713
# 0    1516
# Name: target, dtype: int64

# %%
btc
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                     open          high           low         close  \
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-07-16  30297.472656  30437.560547  30089.669922  30249.132812
# 2023-07-17  30249.626953  30336.400391  29685.783203  30145.888672
# 2023-07-18  30147.070312  30233.656250  29556.427734  29856.562500
# 2023-07-19  29862.046875  30184.181641  29794.269531  29913.923828
# 2023-07-21  29803.185547  29940.945312  29741.357422  29782.476562
#
#                  volume  edit_count  sentiment  neg_sentiment      tomorrow  \
# 2014-09-17     21056800    0.833333  -0.122828       0.466667    424.440002
# 2014-09-18     34483200    0.833333  -0.123633       0.466667    394.795990
# 2014-09-19     37919700    0.866667  -0.098696       0.466667    408.903992
# 2014-09-20     36863600    0.866667  -0.092632       0.466667    398.821014
# 2014-09-21     26580100    0.866667  -0.034374       0.433333    402.152008
# ...                 ...         ...        ...            ...           ...
# 2023-07-16   8516564470    0.066667   0.000135       0.033333  30145.888672
# 2023-07-17  13240156074    0.066667   0.000135       0.033333  29856.562500
# 2023-07-18  13138897269    0.100000  -0.033184       0.066667  29913.923828
# 2023-07-19  12128602812    0.100000  -0.033184       0.066667  29782.476562
# 2023-07-21  14650397696    0.100000  -0.033184       0.066667           NaN
#
#             target
# 2014-09-17       0
# 2014-09-18       0
# 2014-09-19       1
# 2014-09-20       0
# 2014-09-21       1
# ...            ...
# 2023-07-16       0
# 2023-07-17       0
# 2023-07-18       1
# 2023-07-19       0
# 2023-07-21       0
#
# [3229 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=50, random_state=1)

train = btc.iloc[:-200]
test = btc.iloc[-200:]

predictors = ["close", "volume", "open", "high", "low", "edit_count", "sentiment", "neg_sentiment"]
model.fit(train[predictors], train["target"])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["target"], preds)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.5806451612903226

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="predictions")
    combined = pd.concat([test["target"], preds], axis=1)
    return combined
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def backtest(data, model, predictors, start=1095, step=150):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)

    return pd.concat(all_predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(random_state=1, learning_rate=.1, n_estimators=200)
predictions = backtest(btc, model, predictors)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
predictions["predictions"].value_counts()

# %%
precision_score(predictions["target"], predictions["predictions"])

# %%
def compute_rolling(btc):
    horizons = [2,7,60,365]
    new_predictors = ["close", "sentiment", "neg_sentiment"]

    for horizon in horizons:
        rolling_averages = btc.rolling(horizon, min_periods=1).mean()

        ratio_column = f"close_ratio_{horizon}"
        btc[ratio_column] = btc["close"] / rolling_averages["close"]

        edit_column = f"edit_{horizon}"
        btc[edit_column] = rolling_averages["edit_count"]

        rolling = btc.rolling(horizon, closed='left', min_periods=1).mean()
        trend_column = f"trend_{horizon}"
        btc[trend_column] = rolling["target"]

        new_predictors+= [ratio_column, trend_column, edit_column]
    return btc, new_predictors

# %%
btc, new_predictors = compute_rolling(btc.copy())

# %%
predictions = backtest(btc, model, new_predictors)

# %%
precision_score(predictions["target"], predictions["predictions"])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.5058717253839206

# %%
predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             target  predictions
# 2017-09-16       0            1
# 2017-09-17       1            1
# 2017-09-18       0            0
# 2017-09-19       0            1
# 2017-09-20       0            1
# ...            ...          ...
# 2023-07-16       0            0
# 2023-07-17       0            0
# 2023-07-18       1            0
# 2023-07-19       0            0
# 2023-07-21       0            0
#
# [2134 rows x 2 columns]
